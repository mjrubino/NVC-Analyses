# %% [markdown]
# # Table of contents
# 1. [Purpose](#purpose)
# 2. [Inputs](#inputs)
#     * [2.1 SQL Databases](#subinput1)
# 3. [Outputs](#outputs)
# 4. [Constraints](#constraints)
# 5. [Dependencies](#dependencies)
#     * [5.1 Code Language](#codelanguage)
#       * [5.1.1 package requirements](#packagerequirements)
#
# 6. [Code](#code)
# 7. [Tests](#tests)
# 8. [Provenance](#provenance)
# 9. [Citations](#citations)
# ---
#
# # GAP Species Habitat Associations and the National Vegetation Classification (NVC) System Hierarchy
# <br/>
#
# ## Purpose <a name="purpose"></a>
# The U.S. Geological Survey Gap Analysis Project (GAP) created habitat maps for 1590 terrestrial vertebrate species throughout the conterminous US (CONUS), including 219 sub-species. Each species was associated with one or more land cover types represented in the National GAP Land Cover Map (McKerrow et al. 2018, Gergely et al. 2019). The USGS GAP Land Cover Map used vegetation classes based on NatureServe’s Ecological Systems Classification (Comer et al. 2003) and land cover classes described in the National Land Cover Dataset (Homer et al. 2007). These data described vegetation communities at a level of thematic detail useful for ascribing habitat types for species. A crosswalk of that map legend with the nested hierarchy of the US National Vegetation Classification (NVC) permits the assessment of species habitat extents throughtout a broadening thematic vegetation classification.
#
# This notebook specifically outlines using the crosswalk of species habitat associations in the GAP land cover map with NVC macrogroups for linking USDA Forest Inventory and Analysis (FIA) plot level forest composition and structure data.
#
# ## Inputs <a name="inputs"></a>
# The code in this notebook is a first step in combining GAP species habitat association information with FIA plot level data wherein forest structure and composition are tied to NVC macrogroup classes. Since the GAP habitat maps were developed using deductive methods (McKerrow et al. 2018, Gergely et al. 2019) which include landscape attributes other than land cover, it was necessary to identify species whose associations include forest and no other ancillary data such as distance to water or elevation limits.
#
# Data compiled by code in this notebook are assembled in a wildlife habitat relationship database (WHRdb). The WHRdb was queried to compile a list of species associated with at least one forested land cover type (referred to as <b>map units</b> in WHRdb tables) and no ancillary landscape attributes. Modeling parameters were assembled for each species by seasonality - summer (breeding for migratory birds), winter, and year-round (habitat utilized during both summer and winter). Additionally, modeling regions were used to stratify the CONUS into six regions (Northwest, Southwest, Great Plains, Upper Midwest, Southeast, and Northeast). These regions allowed for efficient processing of the species distribution models on smaller, ecologically homogenous extents. Therefore, species habitat associations may occur in multiple seasons and/or across multiple regions. A species model code was developed to maintain unique season/region combinations.
#
# * **U.S. Geological Survey Gap Analysis Project (GAP) Wildlife Habitat Relationship Database** <a name="subinput1"></a>
# Information about access to a given instance of this database is pending. The database is described here: https://www.sciencebase.gov/catalog/item/527d0a83e4b0850ea0518326.
#
# Additionally, this code utilizes an SQL server database that was assembled by intersecting numerous spatial data layers including the PAD-US, species habitat maps, boundary layers such as states, counties, LCCs, ecoregions, etc.
#
# * **U.S. Geological Survey Gap Analysis Project (GAP) Analytical Database** <a name="subinput1"></a>
# These analyses utilize the GAP Analytic database developed by Linda Schueck, Anne Davidson, and Leah Dunn at Boise State University. Information about access to a given instance of this database is pending. The database is described here: https://www.sciencebase.gov/catalog/item/5b736251e4b0f5d5787c61df.
#
# At the time this workflow was developed, both databases were available on a local server. Hence, all code references a local instance of these databases. This code is only replicable given access to a local instance of these databases.
#
# This analysis relies on three major datasets within the analytic database including:
# 1. The detailed land cover dataset: GAP/LANDFIRE National Terrestrial Ecosystems 2011: National Inventory of Vegetation and Land Use  (https://www.sciencebase.gov/catalog/item/5810cd6fe4b0f497e7975237)
# 2. The U.S. National Vegetation Classification Ver 2.0 (http://usnvc.org/explore-classification/)
# 3. A crosswalk between Ecological Systems and the USNVC Types (Embedded in the Attribute file for the National Terrestrials Ecosystems data https://www.sciencebase.gov/catalog/item/5810cd6fe4b0f497e7975237.
#
# ## Outputs <a name="outputs"></a>
# A table and output CSV file with data on species map unit and NVC macrogroup associations organized by season and modeling region. The following columns are included in the table:
# * <b>ScientificName</b> - species scientific name
# * <b>CommonName</b> - species common name
# * <b>SC</b> - species 6-letter code
# * <b>SMC</b> - species 9-charcter model code
# * <b>MUCode</b> - land cover map unit 4-digit code
# * <b>MUName</b> - land cover map unit name
# * <b>Season</b> - species model season
# * <b>Region</b> - species model region
# * <b>Macrogroup</b> - NVC macrogroup name
#
#
# ## Constraints <a name="constraints"></a>
# The Land Cover data attempts to map as accurately as possible the fine vegetative details of the nation’s vegetation. However, there are some limitations to the data that users should keep in mind. The data set uses a 30 meter pixel cell and in most areas a minimum mapping unit of 0.4 ha (1 acre). This means that small patches of vegetation can be missed in the modeling process.  The USNVC is a dynamic content standard, reflecting the state of the science at any point in time; therefore this analysis represents the conservation assessment based on the types that were named and described in the 2017 release of the classification.
#
# ## Dependencies <a name="dependencies"></a>
# These analyses are currently reliant on a local instance of the GAP Wildlife Habitat Relationship database (GAP WHRdb) and the GAP Analytical Database (GAP analytic db).
#
# Code execution dependencies
#
# * **Code Language** <a name="codelanguage"></a>
# This code is written in Python 3.x. Earlier versions may be compatible given slight alterations in syntax and package components.
#   * **Python package requirements** <a name="packagerequirements"></a>
#   The required packages for proper code execution inlclude:
#     - Pandas version 0.2x or above
#     - pyodbc version 4.x or above
#
#
# ## Tests <a name="tests"></a>
# In developing this code the results were compared against a dataset generated through an independent spatial analysis.
#
#
# ## Provenance <a name="provenance"></a>

# %% [markdown]
# ## Code <a name="code"></a>

# %% [markdown]
# #### Import required Python packages

# %%
import pyodbc
import pandas as pd
import pandas.io.sql as psql
#%matplotlib notebook

# %% [markdown]
# #### Accessing the local SQL server instance of the GAP Analytic database

# %%
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#            ++++ Directory Locations ++++
workDir = 'C:/Data/USGS Analyses/NVC-Analyses/Scripts/'


#############################################################################################
################################### LOCAL FUNCTIONS #########################################
#############################################################################################


## --------------Cursor and Database Connections--------------------

def ConnectToDB(connectionStr):
    '''
    (str) -> cursor, connection

    Provides a cursor within and a connection to the database

    Argument:
    connectionStr -- The SQL Server compatible connection string
        for connecting to a database
    '''
    try:
        con = pyodbc.connect(connectionStr)
    except:
        connectionStr = connectionStr.replace('11.0', '10.0')
        con = pyodbc.connect(connectionStr)

    return con.cursor(), con

## ----------------Database Connection----------------------

def DBConnection(dbname):
    '''
    Returns a cursor and connection within the GAP analytic database.
    '''
    # Database connection parameters
    dbstr = """DRIVER=SQL Server Native Client 11.0;
                    SERVER=CHUCK\SQL2014;
                    UID=;
                    PWD=;
                    TRUSTED_CONNECTION=Yes;
                    DATABASE={0};"""
    dbConStr = dbstr.format(dbname)

    return ConnectToDB(dbConStr)

#############################################################################################
#############################################################################################
#############################################################################################

# %%
## Connect to the Analytic Database
print("+"*45)
print("Connecting to Database ....")
cur, conn = DBConnection('GAP_AnalyticDB')
# Out:
# +++++++++++++++++++++++++++++++++++++++++++++
# Connecting to Database ....

# %% [markdown]
# #### Generating an SQL string to pass to a pandas dataframe

# %%
# Make an SQL that pulls out NVC macrogroups from the Analytic db
sqlGA = """SELECT
            level3,
            nvc_macro AS Macrogroup
        FROM
            GAP_AnalyticDB.dbo.gap_landfire"""

# %% [markdown]
# #### Passing the SQL and getting a pandas dataframe

# %%
# Make a dataframe of the macrogroups with the 4-digit code
print("Creating Dataframe of NVC Macrogroups from Gap Analytic Datbase ....")
dfMacro = psql.read_sql(sqlGA, conn)
# Out:
# Creating Dataframe of NVC Macrogroups from Gap Analytic Datbase ....

# %%
dfMacro
# Out:
#      level3                                         Macrogroup
# 0         0                                                  0
# 1      9238                                    Caribbean Swamp
# 2      9702                                    Caribbean Swamp
# 3      9305                                    Caribbean Swamp
# 4      9236              Western Atlantic & Caribbean Mangrove
# 5      4132               Caribbean Coastal Lowland Dry Forest
# 6      4135               Caribbean Coastal Lowland Dry Forest
# 7      4134               Caribbean Coastal Lowland Dry Forest
# 8      4145                             Longleaf Pine Woodland
# 9      4505                             Longleaf Pine Woodland
# 10     4506                             Longleaf Pine Woodland
# 11     4536                             Longleaf Pine Woodland
# 12     5602                             Longleaf Pine Woodland
# 13     4508                             Longleaf Pine Woodland
# 14     4509                             Longleaf Pine Woodland
# 15     4503                             Longleaf Pine Woodland
# 16     4502                             Longleaf Pine Woodland
# 17     4321                             Longleaf Pine Woodland
# 18     4210  Southeastern Coastal Plain Evergreen Oak - Mix...
# 19     4212  Southeastern Coastal Plain Evergreen Oak - Mix...
# 20     4136  Southeastern Coastal Plain Evergreen Oak - Mix...
# 21     4102              Southern Mesic Mixed Broadleaf Forest
# 22     4150  Southeastern Coastal Plain Evergreen Oak - Mix...
# 23     4129              Southern Mesic Mixed Broadleaf Forest
# 24     4209              Southern Mesic Mixed Broadleaf Forest
# 25     4153  Southeastern Coastal Plain Evergreen Oak - Mix...
# 26     4130  Southeastern Coastal Plain Evergreen Oak - Mix...
# 27     4146  Southeastern Coastal Plain Evergreen Oak - Mix...
# 28     4137  Southeastern Coastal Plain Evergreen Oak - Mix...
# 29     4204              Southern Mesic Mixed Broadleaf Forest
# ..      ...                                                ...
# 555    1401                           Woody Horticultural Crop
# 556    1402                 Herbaceous Agricultural Vegetation
# 557    1403                           Pasture & Hay Field Crop
# 558    8404               Introduced & Semi Natural Vegetation
# 559    8407               Introduced & Semi Natural Vegetation
# 560    8408               Introduced & Semi Natural Vegetation
# 561    8402               Introduced & Semi Natural Vegetation
# 562    8406               Introduced & Semi Natural Vegetation
# 563    8401               Introduced & Semi Natural Vegetation
# 564       0                                                  0
# 565    8501                     Recently Disturbed or Modified
# 566    8101                     Recently Disturbed or Modified
# 567    8108                     Recently Disturbed or Modified
# 568    8107                     Recently Disturbed or Modified
# 569    8106                     Recently Disturbed or Modified
# 570    8301                     Recently Disturbed or Modified
# 571    8303                     Recently Disturbed or Modified
# 572    8304                     Recently Disturbed or Modified
# 573    8302                     Recently Disturbed or Modified
# 574    8103                     Recently Disturbed or Modified
# 575    8102                     Recently Disturbed or Modified
# 576    8502                     Recently Disturbed or Modified
# 577    2104                                         Open Water
# 578    2103                                         Open Water
# 579    2102                                         Open Water
# 580    1301         Quarries, Mines, Gravel Pits and Oil Wells
# 581    1201                                  Developed & Urban
# 582    1202                                  Developed & Urban
# 583    1203                                  Developed & Urban
# 584    1204                                  Developed & Urban
#
# [585 rows x 2 columns]

# %% [markdown]
# #### Delete the cursor and connection to the Analytic database to reuse variables for connection to WHR database

# %%
# Delete the previous db connection variables and reset them for
# connecting to the WHR database
del cur, conn
print('Connecting to Gap WHR Database ....')
cur, conn = DBConnection('GapVert_48_2001')
# Out:
# Connecting to Gap WHR Database ....

# %% [markdown]
# #### Pull out species map unit associations from the WHR for species associated with at least one forested type and no ancillary constraints

# %%
# Make an SQL that gets data for species who have at least one forested map unit
# and have NO ancillary data constraints
sqlWHR = """WITH
NonAncillary AS
(SELECT	strSpeciesModelCode,
		ysnHydroFW,
		ysnHydroOW,
		ysnHydroWV,
		ysnHydroSprings,
		strSalinity,
		strStreamVel,
		intFlowAccMin,
		intFlowAccMax,
		strEdgeType,
		intEdgeEcoWidth,
		strUseForInt,
		strForIntBuffer,
		cbxContPatch,
		cbxNonCPatch,
		intContPatchSize,
		intContPatchBuffIn,
		intContPatchBuffFrom,
		intNonCPatchPerc,
		intNonCPatchArea,
		intPercentCanopy,
		intAuxBuff,
		strAvoid,
		ysnUrbanExclude,
		ysnUrbanInclude,
		intElevMin,
		intElevMax,
		intSlopeMin,
		intSlopeMax
FROM GapVert_48_2001.dbo.tblModelAncillary
WHERE	strSpeciesModelCode Not Like '%0' AND
		ysnHydroFW = 0 AND 
		ysnHydroOW = 0 AND 
		ysnHydroWV = 0 AND 
		ysnHydroSprings = 0 AND 
		strSalinity Is Null AND 
		strStreamVel Is Null AND 
		intFlowAccMin Is Null AND 
		intFlowAccMax Is Null AND 
		strEdgeType Is Null AND 
		intEdgeEcoWidth Is Null AND 
		strUseForInt Is Null AND 
		strForIntBuffer Is Null AND 
		cbxContPatch = 0 AND 
		cbxNonCPatch = 0 AND 
		intContPatchSize Is Null AND 
		intContPatchBuffIn Is Null AND 
		intContPatchBuffFrom Is Null AND 
		intNonCPatchPerc Is Null AND 
		intNonCPatchArea Is Null AND 
		intPercentCanopy Is Null AND 
		intAuxBuff Is Null AND 
		strAvoid Is Null AND 
		ysnUrbanExclude = 0 AND 
		ysnUrbanInclude = 0 AND 
		intElevMin Is Null AND 
		intElevMax Is Null AND 
		intSlopeMin Is Null AND 
		intSlopeMax Is Null
),



ForestSelected AS 
(SELECT 
	tblMapUnitDesc.intLSGapMapCode, tblMapUnitDesc.strLSGapName, tblMapUnitDesc.intForest,
	tblSppMapUnitPres.strSpeciesModelCode, tblSppMapUnitPres.ysnPres
FROM
	tblMapUnitDesc FULL JOIN tblSppMapUnitPres
	ON
	tblMapUnitDesc.intLSGapMapCode = tblSppMapUnitPres.intLSGapMapCode
WHERE
	tblMapUnitDesc.intForest = 1 AND
	tblSppMapUnitPres.ysnPres = 1 AND
	tblSppMapUnitPres.strSpeciesModelCode Not Like '%m_'),


Taxa AS
(SELECT
	strUC,
	strSciName,
	strComName
FROM
	GapVert_48_2001.dbo.tblTaxa
)

SELECT 
	Taxa.strSciName AS ScientificName,
	Taxa.strComName AS CommonName,
	Taxa.strUC AS SC,
	NonAncillary.strSpeciesModelCode AS SMC,
	ForestSelected.intLSGapMapCode AS MUCode,
	ForestSelected.strLSGapName AS MUName,
		CASE 
			WHEN 
			  SUBSTRING(NonAncillary.strSpeciesModelCode, 8, 1)='y'
			  THEN 'year-round'
			WHEN
			  SUBSTRING(NonAncillary.strSpeciesModelCode, 8, 1)='s'
			  THEN 'summer'
			WHEN
			  SUBSTRING(NonAncillary.strSpeciesModelCode, 8, 1)='w'
			  THEN 'winter'
		END AS Season,
		
		CASE 
			WHEN 
			  SUBSTRING(NonAncillary.strSpeciesModelCode, 9, 1)='1'
			  THEN 'Northwest'
			WHEN
			  SUBSTRING(NonAncillary.strSpeciesModelCode, 9, 1)='2'
			  THEN 'Upper Midwest'
			WHEN
			  SUBSTRING(NonAncillary.strSpeciesModelCode, 9, 1)='3'
			  THEN 'Northeast'
			WHEN
			  SUBSTRING(NonAncillary.strSpeciesModelCode, 9, 1)='4'
			  THEN 'Southwest'
			WHEN
			  SUBSTRING(NonAncillary.strSpeciesModelCode, 9, 1)='5'
			  THEN 'Great Plains'
			WHEN
			  SUBSTRING(NonAncillary.strSpeciesModelCode, 9, 1)='6'
			  THEN 'Southeast'
		END AS Region

FROM
	NonAncillary INNER JOIN ForestSelected
	ON NonAncillary.strSpeciesModelCode = ForestSelected.strSpeciesModelCode
	INNER JOIN Taxa ON SUBSTRING(NonAncillary.strSpeciesModelCode, 1, 6) = Taxa.strUC"""

# %% [markdown]
# #### Make a dataframe using the above criteria

# %%
# Make a dataframe of the forest/non-ancillary species map unit associations
dfSppMUs = psql.read_sql(sqlWHR, conn)

# %%
dfSppMUs
# Out:
#                 ScientificName                      CommonName      SC  \
# 0             Tantilla relicta           Florida Crowned Snake  rFCSNx
# 1             Myotis lucifugus             Little Brown Myotis  mLBMYx
# 2            Neotoma floridana                 Eastern Woodrat  mEAWOx
# 3         Archilochus colubris       Ruby-throated Hummingbird  bRTHUx
# 4              Regulus satrapa          Golden-crowned Kinglet  bGCKIx
# 5            Corvus ossifragus                       Fish Crow  bFICRx
# 6            Corvus ossifragus                       Fish Crow  bFICRx
# 7            Neotoma floridana                 Eastern Woodrat  mEAWOx
# 8       Zonotrichia albicollis          White-throated Sparrow  bWTSPx
# 9            Melospiza melodia                    Song Sparrow  bSOSPx
# 10           Regulus calendula            Ruby-crowned Kinglet  bRCKIx
# 11          Dryocopus pileatus             Pileated Woodpecker  bPIWOx
# 12           Corvus ossifragus                       Fish Crow  bFICRx
# 13             Regulus satrapa          Golden-crowned Kinglet  bGCKIx
# 14           Corvus ossifragus                       Fish Crow  bFICRx
# 15          Geothlypis trichas             Common Yellowthroat  bCOYEx
# 16      Euphagus cyanocephalus              Brewer's Blackbird  bBRBLx
# 17            Anthus rubescens                  American Pipit  bAMPIx
# 18            Anthus rubescens                  American Pipit  bAMPIx
# 19           Neotoma floridana                 Eastern Woodrat  mEAWOx
# 20      Zonotrichia albicollis          White-throated Sparrow  bWTSPx
# 21           Melospiza melodia                    Song Sparrow  bSOSPx
# 22              Buteo lineatus             Red-shouldered Hawk  bRSHAx
-w6    9836  Mississippi River Low Floodplain (Bottomland) ...
# 14     bFICRx-s3    9836  Mississippi River Low Floodplain (Bottomland) ...
# 15     bCOYEx-w6    9836  Mississippi River Low Floodplain (Bottomland) ...
# 16     bBRBLx-w6    9836  Mississippi River Low Floodplain (Bottomland) ...
# 17     bAMPIx-w6    9836  Mississippi River Low Floodplain (Bottomland) ...
# 18     bAMPIx-w6    9827  Mississippi River Riparian Forest             ...
# 19     mEAWOx-y6    9806  Southern Piedmont Large Floodplain Forest - Fo...
# 20     bWTSPx-w6    9806  Southern Piedmont Large Floodplain Forest - Fo...
# 21     bSOSPx-w6    9806  Southern Piedmont Large Floodplain Forest - Fo...
# 22     bRSHAx-y3    9806  Southern Piedmont Large Floodplain Forest - Fo...
# 23     bPIWOx-y3    9806  Southern Piedmont Large Floodplain Forest - Fo...
# 24     bHETHx-w3    9806  Southern Piedmont Large Floodplain Forest - Fo...
# 25     bGCKIx-w6    9806  Southern Piedmont Large Floodplain Forest - Fo...
# 26     bFICRx-y6    9806  Southern Piedmont Large Floodplain Forest - Fo...
# 27     bFICRx-s3    9806  Southern Piedmont Large Floodplain Forest - Fo...
# 28     bCOYEx-w6    9806  Southern Piedmont Large Floodplain Forest - Fo...
# 29     bBRBLx-w6    9806  Southern Piedmont Large Floodplain Forest - Fo...
# ...          ...     ...                                                ...
# 19307  mKEMYx-s6    4312  Western Great Plains Dry Bur Oak Forest and Wo...
# 19308  bAMWOx-w3    4330  Central Appalachian Oak and Pine Forest       ...
# 19309  mFOSHx-y1    8106  Harvested Forest - Northwestern Conifer Regene...
# 19310  aSRBSx-y2    4330  Central Appalachian Oak and Pine Forest       ...
# 19311  aSRBSx-y2    4205  East Gulf Coastal Plain Northern Mesic Hardwoo...
# 19312  aSRBSx-y2    4337               Northern Crowley's Ridge Sand Forest
# 19313  mRESQx-y3    4123  North-Central Interior Beech-Maple Forest     ...
# 19314  mSBLEx-y5    9803  Central Appalachian Riparian - Forest Modifier...
# 19315  mSBLEx-y5    9235  Atlantic Coastal Plain Northern Tidal Wooded S...
# 19316  mWTWOx-y4    4155  Edwards Plateau Dry-Mesic Slope Forest and Woo...
# 19317  mHORSx-y3    9235  Atlantic Coastal Plain Northern Tidal Wooded S...
# 19318  aRISAx-y6    4123  North-Central Interior Beech-Maple Forest     ...
# 19319  aRISAx-y6    9839  West Gulf Coastal Plain Small Stream and River...
# 19320  aSQSAx-y6    9839  West Gulf Coastal Plain Small Stream and River...
# 19321  aERBSx-y3    4330  Central Appalachian Oak and Pine Forest       ...
# 19322  aERBSx-y3    4323  Laurentian-Acadian Northern Pine-(Oak) Forest ...
# 19323  aERBSx-y3    4123  North-Central Interior Beech-Maple Forest     ...
# 19324  aERBSx-y2    4330  Central Appalachian Oak and Pine Forest       ...
# 19325  aERBSx-y2    4323  Laurentian-Acadian Northern Pine-(Oak) Forest ...
# 19326  aERBSx-y2    4123  North-Central Interior Beech-Maple Forest     ...
# 19327  rDHNSx-y5    4541  East-Central Texas Plains Pine Forest and Wood...
# 19328  rDHNSx-y5    4155  Edwards Plateau Dry-Mesic Slope Forest and Woo...
# 19329  rDHNSx-y5    4312  Western Great Plains Dry Bur Oak Forest and Wo...
# 19330  rDHNSx-y5    9839  West Gulf Coastal Plain Small Stream and River...
# 19331  mROVOx-y3    9803  Central Appalachian Riparian - Forest Modifier...
# 19332  mROVOx-y3    4323  Laurentian-Acadian Northern Pine-(Oak) Forest ...
# 19333  mBASHx-y5    4155  Edwards Plateau Dry-Mesic Slope Forest and Woo...
# 19334  mSAMBx-y4    4155  Edwards Plateau Dry-Mesic Slope Forest and Woo...
# 19335  aSCSAx-y1    8106  Harvested Forest - Northwestern Conifer Regene...
# 19336  aSCSAx-y1    4523  North Pacific Mountain Hemlock Forest         ...
#
#            Season         Region
# 0      year-round      Southeast
# 1          winter      Southeast
# 2      year-round      Southeast
# 3          winter      Southeast
# 4          winter      Southeast
# 5      year-round      Southeast
# 6          summer      Northeast
# 7      year-round      Southeast
# 8          winter      Southeast
# 9          winter      Southeast
# 10         winter  Upper Midwest
# 11     year-round  Upper Midwest
# 12     year-round      Southeast
# 13         winter      Southeast
# 14         summer      Northeast
# 15         winter      Southeast
# 16         winter      Southeast
# 17         winter      Southeast
# 18         winter      Southeast
# 19     year-round      Southeast
# 20         winter      Southeast
# 21         winter      Southeast
# 22     year-round      Northeast
# 23     year-round      Northeast
# 24         winter      Northeast
# 25         winter      Southeast
# 26     year-round      Southeast
# 27         summer      Northeast
# 28         winter      Southeast
# 29         winter      Southeast
# ...           ...            ...
# 19307      summer      Southeast
# 19308      winter      Northeast
# 19309  year-round      Northwest
# 19310  year-round  Upper Midwest
# 19311  year-round  Upper Midwest
# 19312  year-round  Upper Midwest
# 19313  year-round      Northeast
# 19314  year-round   Great Plains
# 19315  year-round   Great Plains
# 19316  year-round      Southwest
# 19317  year-round      Northeast
# 19318  year-round      Southeast
# 19319  year-round      Southeast
# 19320  year-round      Southeast
# 19321  year-round      Northeast
# 19322  year-round      Northeast
# 19323  year-round      Northeast
# 19324  year-round  Upper Midwest
# 19325  year-round  Upper Midwest
# 19326  year-round  Upper Midwest
# 19327  year-round   Great Plains
# 19328  year-round   Great Plains
# 19329  year-round   Great Plains
# 19330  year-round   Great Plains
# 19331  year-round      Northeast
# 19332  year-round      Northeast
# 19333  year-round   Great Plains
# 19334  year-round      Southwest
# 19335  year-round      Northwest
# 19336  year-round      Northwest
#
# [19337 rows x 8 columns]

# %% [markdown]
# ### Merge the two dataframes derived from the Analytic and WHR databases to show map units-macrogroups

# %%
# Merge the dataframes from the WHR and Analytc dbs using the columns
# that have map unit 4-digit codes: MUCode and level3 respectively
dfSppMUs_Macro = pd.merge(left=dfSppMUs, right=dfMacro, how='inner',
                      left_on='MUCode', right_on='level3')

# %%
dfSppMUs_Macro=dfSppMUs_Macro.sort_values(by=['SMC'])
dfSppMUs_Macro
# Out:
#                  ScientificName                     CommonName      SC  \
# 6951           Aneides lugubris            Arboreal Salamander  aARSAx
# 6939           Aneides lugubris            Arboreal Salamander  aARSAx
# 17623      Plethodon caddoensis      Caddo Mountain Salamander  aCMSAx
# 14016      Plethodon caddoensis      Caddo Mountain Salamander  aCMSAx
# 14166      Plethodon caddoensis      Caddo Mountain Salamander  aCMSAx
# 12753        Plethodon kentucki  Cumberland Plateau Salamander  aCPSAx
# 10074        Plethodon kentucki  Cumberland Plateau Salamander  aCPSAx
# 16448   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 6814    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 1128    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 2754    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 11304   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 3352    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 7019    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 11559   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 15340   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 12153   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 7896    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 11417   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 6753    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 3078    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 6151    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 4909    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 4950    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 4833    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 10666   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 18119   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 11112   Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 9298    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# 6802    Batrachoseps attenuatus  California Slender Salamander  aCSLSx
# ...                         ...                            ...     ...
# 13935  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 3906   Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 13203  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 17740  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 17241  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 7210   Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 7443   Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 10826  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 1045   Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 8833   Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 8907   Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 15742  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 8010   Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 12801  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 9757   Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 11065  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 10290  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 7653   Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 16409  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 4272   Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 10382  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 9668   Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 5766   Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 16880  Lampropeltis calligaster       Yellow-bellied Kingsnake  rYBKIx
# 11333      Sceloporus uniformis     Yellow-backed Spiny Lizard  rYBSLx
# 7104       Sceloporus uniformis     Yellow-backed Spiny Lizard  rYBSLx
# 6696       Sceloporus uniformis     Yellow-backed Spiny Lizard  rYBSLx
# 5910       Sceloporus uniformis     Yellow-backed Spiny Lizard  rYBSLx
# 1643      Gonatodes albogularis            Yellow-headed Gecko  rYHGEx
# 12049     Gonatodes albogularis            Yellow-headed Gecko  rYHGEx
#
#              SMC  MUCode                                             MUName  \
# 6951   aARSAx-y1    4317  Mediterranean California Lower Montane Black O...
# 6939   aARSAx-y4    4317  Mediterranean California Lower Montane Black O...
# 17623  aCMSAx-y6    4207  Ozark-Ouachita Mesic Hardwood Forest          ...
# 14016  aCMSAx-y6    4122  Ouachita Montane Oak Forest                   ...
# 14166  aCMSAx-y6    4115  Ozark-Ouachita Dry-Mesic Oak Forest           ...
# 12753  aCPSAx-y6    4401  Southern and Central Appalachian Cove Forest  ...
# 10074  aCPSAx-y6    4402  South-Central Interior Mesophytic Forest      ...
# 16448  aCSLSx-y1    4148  North Pacific Broadleaf Landslide Forest and S...
# 6814   aCSLSx-y1    4317  Mediterranean California Lower Montane Black O...
# 1128   aCSLSx-y1    9811  North Pacific Lowland Riparian Forest and Shru...
# 2754   aCSLSx-y1    8201                               Deciduous Plantation
# 11304  aCSLSx-y1    4519  Mediterranean California Dry-Mesic Mixed Conif...
# 3352   aCSLSx-y1    8203                            Managed Tree Plantation
# 7019   aCSLSx-y1    4603  Mediterranean California Mesic Mixed Conifer F...
# 11559  aCSLSx-y1    4320  Mediterranean California Mixed Evergreen Fores...
# 15340  aCSLSx-y1    4338  North Pacific Lowland Mixed Hardwood-Conifer F...
# 12153  aCSLSx-y1    8401               Introduced Upland Vegetation - Treed
# 7896   aCSLSx-y1    4607  North Pacific Mesic Western Hemlock-Silver Fir...
# 11417  aCSLSx-y1    4319  North Pacific Dry Douglas-fir-(Madrone) Forest...
# 6753   aCSLSx-y1    4604  North Pacific Hypermaritime Sitka Spruce Fores...
# 3078   aCSLSx-y1    8202               Evergreen Plantation or Managed Pine
# 6151   aCSLSx-y1    4613  North Pacific Hypermaritime Western Red-cedar-...
# 4909   aCSLSx-y1    4606  North Pacific Maritime Mesic-Wet Douglas-fir-W...
# 4950   aCSLSx-y1    8106  Harvested Forest - Northwestern Conifer Regene...
# 4833   aCSLSx-y1    4533  Sierra Nevada Subalpine Lodgepole Pine Forest ...
# 10666  aCSLSx-y1    4522  North Pacific Maritime Dry-Mesic Douglas-fir-W...
# 18119  aCSLSx-y1    4545  California Coastal Closed-Cone Conifer Forest ...
# 11112  aCSLSx-y1    4547  North Pacific Dry-Mesic Silver Fir-Western Hem...
# 9298   aCSLSx-y1    4601  California Coastal Redwood Forest             ...
# 6802   aCSLSx-y4    4604  North Pacific Hypermaritime Sitka Spruce Fores...
# ...          ...     ...                                                ...
# 13935  rYBKIx-y5    4120  North-Central Interior Dry-Mesic Oak Forest an...
# 3906   rYBKIx-y5    4541  East-Central Texas Plains Pine Forest and Wood...
# 13203  rYBKIx-y5    4137  West Gulf Coastal Plain Chenier and Upper Texa...
# 17740  rYBKIx-y5    4321  West Gulf Coastal Plain Upland Longleaf Pine F...
# 17241  rYBKIx-y5    4121  North-Central Interior Dry Oak Forest and Wood...
# 7210   rYBKIx-y5    4553  Atlantic Coastal Plain Fall-line Sandhills Lon...
# 7443   rYBKIx-y5    4136  Central and South Texas Coastal Fringe Forest ...
# 10826  rYBKIx-y6    4308  Southern Ridge and Valley Dry Calcareous Fores...
# 1045   rYBKIx-y6    9911  East Gulf Coastal Plain Southern Loblolly-Hard...
#
# 15742  Appalachian-Northeastern Oak - Hardwood - Pine...
# 8010   Appalachian-Northeastern Oak - Hardwood - Pine...
# 12801  Southern & South-Central Oak - Hickory - Pine ...
# 9757   Appalachian-Northeastern Oak - Hardwood - Pine...
# 11065         Southeastern North American Ruderal Forest
# 10290         Southeastern North American Ruderal Forest
# 7653          Southeastern North American Ruderal Forest
# 16409  Southern & South-Central Oak - Hickory - Pine ...
# 4272   Southern & South-Central Oak - Hickory - Pine ...
# 10382              Southern Mesic Mixed Broadleaf Forest
# 9668          Southeastern North American Ruderal Forest
# 5766   Southern & South-Central Oak - Hickory - Pine ...
# 16880  Appalachian-Northeastern Oak - Hardwood - Pine...
# 11333      Southern Vancouverian Montane-Foothill Forest
# 7104       Southern Vancouverian Montane-Foothill Forest
# 6696                   Madrean Montane Forest & Woodland
# 5910                   Madrean Montane Forest & Woodland
# 1643                                     Caribbean Swamp
# 12049               Caribbean Coastal Lowland Dry Forest
#
# [19163 rows x 10 columns]

# %% [markdown]
# ### Export the data to a CSV file

# %%
# Export to CSV file
dfSppMUs_Macro.to_csv(workDir + "Species-Habitat-Macrogroups.csv")

# %% [markdown]
# ## Citations <a name="citations"></a>
# Comer, P.J., Faber-Langendoen D., Evans, R., Gawler, S.C., Josse, C., Kittel, G., Menard, S., Pyne, M., Reid, M., Schulz, K., Snow, K., and Teague, J., 2003, Ecological systems of the United States—A working classification of U.S. terrestrial systems: Arlington, NatureServe. [Also available at http://www.natureserve.org/biodiversity-science/publications/ecological-systems-united-states.
#
# Gergely, K.J., Boykin, K.G., McKerrow, A.J., Rubino, M.J., Tarr, N.M., and Williams, S.G., 2019, Gap Analysis Project (GAP) terrestrial vertebrate species richness maps for the conterminous U.S.: U.S. Geological Survey Scientific Investigations Report 2019–5034, 99 p., https://doi.org/10.3133/sir20195034.
#
# Homer, C.J., Dewitz, J., Fry, M., Coan, N., Hossain, C., Larson, N., Herold, A., McKerrow, J.N., VanDriel, J.N., and Wickham, J., 2007, Completion of the 2001 National Land Cover Database for the Conterminous United States: Photogrammetric Engineering and Remote Sensing, v. 73, issue 4, p. 337–341, accessed July 30, 2018, at https://www.researchgate.net/profile/Collin_Homer/publication/237239863_Completion_of_the_2001_National_Land_Cover_Database_for_the_Conterminous_United_States/links/0046352ab204d93a3e000000.pdf.
#
# McKerrow, A.J., Tarr, N.M., Rubino, M.J., and Williams, S.G., 2018, Patterns of species richness hotspots and estimates of their protection are sensitive to spatial resolution: Diversity and Distributions, v. 24, issue 10, p. 1464–1477, accessed July 30, 2018, at https://doi.org/10.1111/ddi.12779.
#
# U.S. Geological Survey Gap Analysis Program, 20160513, GAP/LANDFIRE National Terrestrial Ecosystems 2011: U.S. Geological Survey, https://doi.org/10.5066/F7ZS2TM0.
#
# USNVC [United States National Vegetation Classification]. 2017. United States National Vegetation Classification Database, V2.01. Federal Geographic Data Committee, Vegetation Subcommittee, Washington DC. [usnvc.org/explore-classification/] (accessed 30 March 2017).
